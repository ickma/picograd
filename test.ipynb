# %%
from sklearn.datasets import load_digits, load_iris

from sklearn.model_selection import train_test_split

import numpy as np

# %%
digits = load_iris()
print(digits.data.shape)
print(digits.target.shape)
# Out:
# (150, 4)
# (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    digits.data/np.max(digits.data), digits.target, test_size=0.1, random_state=42)

# %%
from nn.layer import Layer


class Model:
    def __init__(self, in_dim, out_dim):
        self.layer1 = Layer(in_dim, 5)
        self.layer2 = Layer(5, 5)
        self.layer3 = Layer(5, out_dim)
        self.in_dim = in_dim
        self.out_dim = out_dim

    def forward(self, x):
        out = self.layer1.forward(x)
        out = [x.relu() for x in out]
        out = self.layer2.forward(out)
        out = [x.relu() for x in out]
        out = self.layer3.forward(out)
        # out = [x.relu() for x in out]
        # Apply softmax activation to the output layer
        exp_out = [x.exp() for x in out]
        sum_exp = sum(exp_out)
        out = [x / sum_exp for x in exp_out]
        return out

    def zero_grad(self):
        for layer in [self.layer1, self.layer2,self.layer3]:
            for p in layer.weights:
                p.grad = 0
            for p in layer.biases:
                p.grad = 0
                
    def learn(self, learning_rate):
 
        for layer in [self.layer1, self.layer2,self.layer3]:
            for p in layer.weights:
                p.value = p.value - (learning_rate * p.grad)
          
            for p in layer.biases:
                p.value = p.value - (learning_rate * p.grad)

# %%
model = Model(len(X_train[0]), len(np.unique(y_train)))

batch_size = len(X_train)//10
epochs = 100

accuracy_list = []

for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")
    learning_rate = .9 / (1 + 0.1 * epoch)  # Stochastic Gradient Descent (SGD) with learning rate decay
    # learning_rate = 0.3
    print(f"learning_rate: {learning_rate}")
    for i in range(0, len(X_train), batch_size):
        model.zero_grad()
        error_list = []
        for j in range(batch_size):
            if i+j >= len(X_train):
                break
            x = (X_train[i+j]/1.0).tolist()
            y = int(y_train[i+j])
            out = model.forward(x)
            # errors = [
            #     (out[i]-1 if i == y else out[i])**2 for i in range(len(out))
            # ]
            # Calculate cross-entropy error
            target = [1 if i == y else 0 for i in range(len(out))]
            errors = [-target[i] * out[i].sigmoid().log() - (1 - target[i]) * (1 - out[i].sigmoid()).log() for i in range(len(out))]
            error_list.extend(errors)
        loss = sum(error_list)/len(error_list)
        loss.grad=1
        loss.backward()
        model.learn(learning_rate)
        # print(f"loss: {loss.value}")

    # evaluate
    correct = 0
    import numpy as np
    for i in range(len(X_test)):
        x = (X_test[i]/1.0).tolist()
        y = int(y_test[i])
        out = model.forward(x)
        if np.argmax([o.value for o in out]) == y:
            correct += 1
 
    print(f"Accuracy: {correct/len(X_test):.2f}")
    accuracy_list.append(correct/len(X_test))
# Out:
# Epoch 1/100
# learning_rate: 0.9
# Accuracy: 0.20
# Epoch 2/100
# learning_rate: 0.8181818181818181
# Accuracy: 0.20
# Epoch 3/100
# learning_rate: 0.75
# Accuracy: 0.20
# Epoch 4/100
# learning_rate: 0.6923076923076923
# Accuracy: 0.60
# Epoch 5/100
# learning_rate: 0.6428571428571429
# Accuracy: 0.60
# Epoch 6/100
# learning_rate: 0.6
# Accuracy: 0.60
# Epoch 7/100
# learning_rate: 0.5625
# Accuracy: 0.60
# Epoch 8/100
# learning_rate: 0.5294117647058824
# Accuracy: 0.60
# Epoch 9/100
# learning_rate: 0.5
# Accuracy: 0.60
# Epoch 10/100
# learning_rate: 0.4736842105263158
# Accuracy: 0.60
# Epoch 11/100
# learning_rate: 0.45
# Accuracy: 0.60
# Epoch 12/100
# learning_rate: 0.42857142857142855
# Accuracy: 0.60
# Epoch 13/100
# learning_rate: 0.40909090909090906
# Accuracy: 0.67
# Epoch 14/100
# learning_rate: 0.391304347826087
# Accuracy: 0.67
# Epoch 15/100
# learning_rate: 0.37499999999999994
# Accuracy: 0.73
# Epoch 16/100
# learning_rate: 0.36
# Accuracy: 0.73
# Epoch 17/100
# learning_rate: 0.34615384615384615
# Accuracy: 0.73
# Epoch 18/100
# learning_rate: 0.3333333333333333
# Accuracy: 0.73
# Epoch 19/100
# learning_rate: 0.32142857142857145
# Accuracy: 0.73
# Epoch 20/100
# learning_rate: 0.31034482758620685
# Accuracy: 0.80
# Epoch 21/100
# learning_rate: 0.3
# Accuracy: 0.80
# Epoch 22/100
# learning_rate: 0.2903225806451613
# Accuracy: 0.87
# Epoch 23/100
# learning_rate: 0.28125
# Accuracy: 0.87
# Epoch 24/100
# learning_rate: 0.2727272727272727
# Accuracy: 0.87
# Epoch 25/100
# learning_rate: 0.2647058823529412
# Accuracy: 0.87
# Epoch 26/100
# learning_rate: 0.2571428571428572
# Accuracy: 0.87
# Epoch 27/100
# learning_rate: 0.25
# Accuracy: 0.87
# Epoch 28/100
# learning_rate: 0.24324324324324323
# Accuracy: 0.87
# Epoch 29/100
# learning_rate: 0.23684210526315788
# Accuracy: 0.87
# Epoch 30/100
# learning_rate: 0.23076923076923075
# Accuracy: 0.87
# Epoch 31/100
# learning_rate: 0.225
# Accuracy: 0.87
# Epoch 32/100
# learning_rate: 0.21951219512195125
# Accuracy: 0.87
# Epoch 33/100
# learning_rate: 0.21428571428571427
# Accuracy: 0.87
# Epoch 34/100
# learning_rate: 0.20930232558139533
# Accuracy: 0.87
# Epoch 35/100
# learning_rate: 0.20454545454545453
# Accuracy: 0.87
# Epoch 36/100
# learning_rate: 0.2
# Accuracy: 0.87
# Epoch 37/100
# learning_rate: 0.1956521739130435
# Accuracy: 0.87
# Epoch 38/100
# learning_rate: 0.19148936170212766
# Accuracy: 0.87
# Epoch 39/100
# learning_rate: 0.18749999999999997
# Accuracy: 0.87
# Epoch 40/100
# learning_rate: 0.18367346938775508
# Accuracy: 0.87
# Epoch 41/100
# learning_rate: 0.18
# Accuracy: 0.87
# Epoch 42/100
# learning_rate: 0.1764705882352941
# Accuracy: 0.87
# Epoch 43/100
# learning_rate: 0.17307692307692307
# Accuracy: 0.87
# Epoch 44/100
# learning_rate: 0.169811320754717
# Accuracy: 0.87
# Epoch 45/100
# learning_rate: 0.16666666666666666
# Accuracy: 0.87
# Epoch 46/100
# learning_rate: 0.16363636363636364
# Accuracy: 0.87
# Epoch 47/100
# learning_rate: 0.1607142857142857
# Accuracy: 0.87
# Epoch 48/100
# learning_rate: 0.15789473684210525
# Accuracy: 0.87
# Epoch 49/100
# learning_rate: 0.15517241379310343
# Accuracy: 0.87
# Epoch 50/100
# learning_rate: 0.15254237288135591
# Accuracy: 0.87
# Epoch 51/100
# learning_rate: 0.15
# Accuracy: 0.87
# Epoch 52/100
# learning_rate: 0.14754098360655737
# Accuracy: 0.87
# Epoch 53/100
# learning_rate: 0.14516129032258066
# Accuracy: 0.87
# Epoch 54/100
# learning_rate: 0.14285714285714285
# Accuracy: 0.87
# Epoch 55/100
# learning_rate: 0.140625
# Accuracy: 0.87
# Epoch 56/100
# learning_rate: 0.13846153846153847
# Accuracy: 0.87
# Epoch 57/100
# learning_rate: 0.13636363636363635
# Accuracy: 0.87
# Epoch 58/100
# learning_rate: 0.13432835820895522
# Accuracy: 0.87
# Epoch 59/100
# learning_rate: 0.1323529411764706
# Accuracy: 0.87
# Epoch 60/100
# learning_rate: 0.13043478260869565
# Accuracy: 0.87
# Epoch 61/100
# learning_rate: 0.1285714285714286
# Accuracy: 0.87
# Epoch 62/100
# learning_rate: 0.1267605633802817
# Accuracy: 0.87
# Epoch 63/100
# learning_rate: 0.125
# Accuracy: 0.87
# Epoch 64/100
# learning_rate: 0.1232876712328767
# Accuracy: 0.87
# Epoch 65/100
# learning_rate: 0.12162162162162161
# Accuracy: 0.87
# Epoch 66/100
# learning_rate: 0.12000000000000001
# Accuracy: 0.87
# Epoch 67/100
# learning_rate: 0.11842105263157894
# Accuracy: 0.87
# Epoch 68/100
# learning_rate: 0.11688311688311688
# Accuracy: 0.87
# Epoch 69/100
# learning_rate: 0.11538461538461538
# Accuracy: 0.87
# Epoch 70/100
# learning_rate: 0.11392405063291139
# Accuracy: 0.93
# Epoch 71/100
# learning_rate: 0.1125
# Accuracy: 0.93
# Epoch 72/100
# learning_rate: 0.11111111111111109
# Accuracy: 0.93
# Epoch 73/100
# learning_rate: 0.10975609756097562
# Accuracy: 0.93
# Epoch 74/100
# learning_rate: 0.10843373493975902
# Accuracy: 0.93
# Epoch 75/100
# learning_rate: 0.10714285714285714
# Accuracy: 0.93
# Epoch 76/100
# learning_rate: 0.10588235294117647
# Accuracy: 0.93
# Epoch 77/100
# learning_rate: 0.10465116279069767
# Accuracy: 0.93
# Epoch 78/100
# learning_rate: 0.10344827586206898
# Accuracy: 0.93
# Epoch 79/100
# learning_rate: 0.10227272727272727
# Accuracy: 0.93
# Epoch 80/100
# learning_rate: 0.10112359550561797
# Accuracy: 0.93
# Epoch 81/100
# learning_rate: 0.1
# Accuracy: 0.93
# Epoch 82/100
# learning_rate: 0.09890109890109891
# Accuracy: 0.93
# Epoch 83/100
# learning_rate: 0.09782608695652173
# Accuracy: 0.93
# Epoch 84/100
# learning_rate: 0.0967741935483871
# Accuracy: 0.93
# Epoch 85/100
# learning_rate: 0.09574468085106383
# Accuracy: 0.93
# Epoch 86/100
# learning_rate: 0.09473684210526316
# Accuracy: 0.93
# Epoch 87/100
# learning_rate: 0.09375
# Accuracy: 0.93
# Epoch 88/100
# learning_rate: 0.09278350515463916
# Accuracy: 0.93
# Epoch 89/100
# learning_rate: 0.09183673469387754
# Accuracy: 0.93
# Epoch 90/100
# learning_rate: 0.09090909090909091
# Accuracy: 0.93
# Epoch 91/100
# learning_rate: 0.09
# Accuracy: 0.93
# Epoch 92/100
# learning_rate: 0.08910891089108912
# Accuracy: 0.93
# Epoch 93/100
# learning_rate: 0.08823529411764705
# Accuracy: 0.93
# Epoch 94/100
# learning_rate: 0.08737864077669903
# Accuracy: 0.93
# Epoch 95/100
# learning_rate: 0.08653846153846154
# Accuracy: 0.93
# Epoch 96/100
# learning_rate: 0.08571428571428572
# Accuracy: 0.93
# Epoch 97/100
# learning_rate: 0.08490566037735849
# Accuracy: 0.93
# Epoch 98/100
# learning_rate: 0.08411214953271028
# Accuracy: 0.93
# Epoch 99/100
# learning_rate: 0.08333333333333333
# Accuracy: 0.93
# Epoch 100/100
# learning_rate: 0.08256880733944955
# Accuracy: 0.93

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), accuracy_list)
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
